# %%
import pandas as pd
data = pd.read_csv("traffic_measurement.csv")
data
# Out:
# Empty DataFrame
# Columns: [Vehicle Type/Size,  Vehicle Color,  Vehicle Movement Direction,  Vehicle Speed (km/h),  Day ,  Month,  Date,  Hours,  Minutes,  Seconds]
# Index: []

# %%
a = pd.read_csv("traffic_measurement.csv")

# %%
a
# Out:
#   Vehicle Type/Size  Vehicle Color  Vehicle Movement Direction  \
# 0               car          white                        down
# 1               car          white                        down
# 2               car          white                        down
# 3               car          white                        down
# 4               car          white                        down
# 5               car          white                        down
# 6               car          white                          up
# 7               car          white                        down
#
#    Vehicle Speed (km/h)  Day   Month   Date   Hours   Minutes   Seconds
# 0     28.86685477362739   Sun    Nov     11      18        19        19
# 1     25.86172315809462   Sun    Nov     11      18        19        19
# 2    19.694523281521267   Sun    Nov     11      18        19        19
# 3    13.201654222276476   Sun    Nov     11      18        19        24
# ...

# %%
b = pd.read_csv("gsf.csv")

# %%
b
# Out:
# Empty DataFrame
# Columns: [Vehicle Type/Size,  Vehicle Color,  Vehicle Movement Direction,  Vehicle Speed (km/h),  Day ,  Month,  Date,  Hours,  Minutes,  Seconds]
# Index: []

# %%
merged = pd.concat([a,b])

# %%
merged
# Out:
#   Vehicle Type/Size  Vehicle Color  Vehicle Movement Direction  \
# 0               car          white                        down
# 1               car          white                        down
# 2               car          white                        down
# 3               car          white                        down
# 4               car          white                        down
# 5               car          white                        down
# 6               car          white                          up
# 7               car          white                        down
#
#    Vehicle Speed (km/h)  Day   Month  Date  Hours  Minutes  Seconds
# 0     28.86685477362739   Sun    Nov    11     18       19       19
# 1     25.86172315809462   Sun    Nov    11     18       19       19
# 2    19.694523281521267   Sun    Nov    11     18       19       19
# 3    13.201654222276476   Sun    Nov    11     18       19       24
# ...

# %%
with open('gsf.csv', 'a') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(merged)
    csvFile.close()
